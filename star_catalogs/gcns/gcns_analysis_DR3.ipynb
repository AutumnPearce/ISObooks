# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import cmasher as cm

# %%
data = pd.read_csv('../files/gcns_DR3.csv')
data
# Out:
#         Unnamed: 0            source_id          RA  RA_ERROR        DEC  \
# 0                0   383095247260963712    2.058686  0.022047  39.728708
# 1                1   383108338321272448    1.977553  0.038781  39.791932
# 2                2   383162661067592192    1.680234  0.128044  40.009855
# 3                3   383167952465316864    1.905896  0.021587  40.147840
# 4                4   383167952467292288    1.907764  0.225813  40.147854
# ...            ...                  ...         ...       ...        ...
# 331306      331306  6533471819377716736  358.771159  0.009305 -41.401665
# 331307      331307  6533483501688768128  358.651669  0.019821 -41.321624
# 331308      331308  6533503464696796928  359.239473  0.008948 -41.013088
# 331309      331309  6533503464696797056  359.237353  0.033996 -41.012712
# 331310      331310  6533569023077625984  358.599516  0.026710 -40.747478
#
#         DEC_ERROR   PARALLAX  PARALLAX_ERROR        PMRA  PMRA_ERROR  ...  \
# 0        0.016036  11.190593        0.030270  -76.268702    0.024213  ...
# 1        0.029635  29.100410        0.057270  359.096889    0.043967  ...
# 2        0.092270  14.690472        0.168487  272.229495    0.143219  ...
# 3        0.019093  11.172839        0.032044  -32.150140    0.027103  ...
# 4        0.170263   9.794068        0.344391  -27.196407    0.273073  ...
# ...           ...        ...             ...         ...         ...  ...
# 331306   0.011389  10.575865        0.015878   -3.030721    0.012908  ...
# 331307   0.023251  14.704621        0.030420  106.865119    0.027199  ...
# 331308   0.011554  12.517269        0.013941   87.464742    0.011966  ...
# 331309   0.045042  12.723253        0.052598   86.783013    0.044988  ...
# 331310   0.041263  10.070683        0.046265   42.502044    0.041052  ...
#
#         distance_gspphot_lower  distance_gspphot_upper  teff_gspphot  \
# 0                      90.3455                 90.9165     3395.2993
# 1                          NaN                     NaN           NaN
# 2                          NaN                     NaN           NaN
# 3                          NaN                     NaN           NaN
# 4                      75.6136                 78.7228     4907.0550
# ...                        ...                     ...           ...
# 331306                 94.1908                 94.5297     5611.3000
# 331307                     NaN                     NaN           NaN
# 331308                 80.4142                 80.5935     4125.3190
# 331309                     NaN                     NaN           NaN
# 331310                     NaN                     NaN           NaN
#
#         teff_gspphot_lower  teff_gspphot_upper  logg_gspphot  \
# 0                3391.0560           3405.7048        4.7682
# 1                      NaN                 NaN           NaN
# 2                      NaN                 NaN           NaN
# 3                      NaN                 NaN           NaN
# 4                4902.6360           4909.7793        2.9687
# ...                    ...                 ...           ...
# 331306           5609.3320           5617.1650        4.2016
# 331307                 NaN                 NaN           NaN
# 331308           4124.0645           4126.6190        4.7023
# 331309                 NaN                 NaN           NaN
# 331310                 NaN                 NaN           NaN
#
#         logg_gspphot_lower  logg_gspphot_upper  ipd_frac_multi_peak  \
# 0                   4.7507              4.8042                    0
# 1                      NaN                 NaN                    0
# 2                      NaN                 NaN                    2
# 3                      NaN                 NaN                    5
# 4                   2.9463              2.9820                    0
# ...                    ...                 ...                  ...
# 331306              4.2006              4.2026                    0
# 331307                 NaN                 NaN                    0
# 331308              4.7008              4.7038                    0
# 331309                 NaN                 NaN                    0
# 331310                 NaN                 NaN                    0
#
#         mass_flame
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4         2.251833
# ...            ...
# 331306         NaN
# 331307         NaN
# 331308         NaN
# 331309         NaN
# 331310         NaN
#
# [331311 rows x 32 columns]

# %% [markdown]
# ## HR Diagram

# %%
# get absolute magnitude
# M = m + 5log(p) + 5
# p in arcseconds, gaia qives in mas
abs_mag = data['phot_g_mean_mag'] + 5*np.log10(data['PARALLAX']/1000) + 5 

# get color
color = data['phot_bp_mean_mag'] - data['phot_g_mean_mag']

# %%
fig,ax = plt.subplots(figsize = (7,7))

ax.set_title('Gaia Stars Within 100 pc', fontsize=20)#, fontname = 'Ayuthaya')
ax.set_ylabel('Absolute Magnitude (G)', fontsize=15)#, fontname = 'Ayuthaya')
ax.set_xlabel('Color (BP-G)', fontsize=15)#, fontname = 'Ayuthaya')

ax.set_ylim([18,-1])
ax.set_xlim([-1,3.7])

# ax.scatter(color,abs_mag, s=.08, alpha=1, color='darkmagenta')
cmap = cm.cm.eclipse
hb = ax.hexbin(color, abs_mag, gridsize=700, bins='log', cmap=cmap)

# Set the facecolor of the hexbin plot to match the lowest density color
ax.set_facecolor(cmap(0))

# %% [markdown]
# ## Radial Velocity Limiting Mag

# %%
# radial velocities seem to be magnitude-limited
has_radvel = np.array(data['RADIAL_VELOCITY'].notnull())
no_radvel = np.logical_not(has_radvel)


fig,ax = plt.subplots(figsize=(8,5))
ax.hist([data[has_radvel]['phot_g_mean_mag'], data[no_radvel]['phot_g_mean_mag']], stacked="True",\
    bins = np.linspace(5, 20),\
    label = ["with velocities", "without velocities"],\
    color = ["steelblue", "darkblue"])
#ax.hist(df_without_vel["Gmag"], stacked = True)
ax.set_yscale("log")

ax.legend()

ax.set_xlabel("Gaia G-Magnitude", fontsize = 12)
ax.set_ylabel("Number of Stars per Bin", fontsize = 12)

plt.show()

# %%
fig,ax = plt.subplots(figsize=(8,5))
ax.set_ylabel("Radial Velocity Error [km/s]")
ax.set_xlabel("Gaia G-Magnitude")
ax.scatter(data['phot_g_mean_mag'],data['RADIAL_VELOCITY_ERROR'],s=.5, color='darkblue')

# %%
mag_13_to_14 = np.logical_and(13<data['phot_g_mean_mag'], data['phot_g_mean_mag']<14)
mag_below_13 = data['phot_g_mean_mag']<13
mag_above_14 = data['phot_g_mean_mag']>14

fig,axs = plt.subplots(ncols=3,figsize=(15,5))

axs[0].hist(data[mag_below_13]['RADIAL_VELOCITY_ERROR'],bins=100)
axs[0].set_title('Mag up to 13')

axs[1].hist(data[mag_13_to_14]['RADIAL_VELOCITY_ERROR'],bins=100)
axs[1].set_title('Mag 13 to 14')

axs[2].hist(data[mag_above_14]['RADIAL_VELOCITY_ERROR'],bins=100)
axs[2].set_title('Mag above 14')

plt.show()

# %% [markdown]
# ## Other Limiting Magnitudes? (no)

# %%
# radial velocities seem to be magnitude-limited
has_radvel = np.array(data['mass_flame'].notnull())
no_radvel = np.logical_not(has_radvel)


fig,ax = plt.subplots(figsize=(8,5))
ax.hist([data[has_radvel]['phot_g_mean_mag'], data[no_radvel]['phot_g_mean_mag']], stacked="True",\
    bins = np.linspace(5, 20),\
    label = ["with mass", "without mass"],\
    color = ["steelblue", "darkblue"])
#ax.hist(df_without_vel["Gmag"], stacked = True)
ax.set_yscale("log")

ax.legend()

ax.set_xlabel("Gaia G-Magnitude", fontsize = 12)
ax.set_ylabel("Number of Stars per Bin", fontsize = 12)

plt.show()

# %%
# radial velocities seem to be magnitude-limited
has_radvel = np.array(data['mh_gspphot'].notnull())
no_radvel = np.logical_not(has_radvel)


fig,ax = plt.subplots(figsize=(8,5))
ax.hist([data[has_radvel]['phot_g_mean_mag'], data[no_radvel]['phot_g_mean_mag']], stacked="True",\
    bins = np.linspace(5, 20),\
    label = ["with metallicity", "without metallicity"],\
    color = ["steelblue", "darkblue"])
#ax.hist(df_without_vel["Gmag"], stacked = True)
ax.set_yscale("log")

ax.legend()

ax.set_xlabel("Gaia G-Magnitude", fontsize = 12)
ax.set_ylabel("Number of Stars per Bin", fontsize = 12)

plt.show()

# %% [markdown]
# ## Find Closest Star w/o Radial Velocity

# %%
# M = m - 5log10(d) + 5
# with M = absolute mag of M9 star = 10ish
# d = 10^[(m-5)/5]
# with m = limiting mag

def limiting_dist(limiting_mag, dimmest_abs_mag=15):
    return 10**((5 + limiting_mag - dimmest_abs_mag)/5)

for limiting_mag in [13,15]:
    print(f"An M9 star has m = {limiting_mag} at d = {limiting_dist(limiting_mag)} pc")
# Out:
# An M9 star has m = 13 at d = 3.9810717055349722 pc
# An M9 star has m = 15 at d = 10.0 pc

# %%
fig,ax = plt.subplots(figsize=(8,5))
ax.hist(has_radvel, bins = 100)
# Out:
# /Users/autumn/opt/anaconda3/envs/astronomy_general/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6854: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/astronomy_general/lib/python3.9/site-packages/numpy/lib/histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 fig,ax = plt.subplots(figsize=(8,5))
# ----> 2 ax.hist(data["mass_flame"].notnull(), bins = 100)
#
# File ~/opt/anaconda3/envs/astronomy_general/lib/python3.9/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/envs/astronomy_general/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6854, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6850 # Loop through datasets
#    6851 for i in range(nx):
#    6852     # this will automatically overwrite bins,
#    6853     # so that each histogram uses the same bins
# -> 6854     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6855     tops.append(m)
#    6856 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File ~/opt/anaconda3/envs/astronomy_general/lib/python3.9/site-packages/numpy/lib/histograms.py:811, in histogram(a, bins, range, density, weights)
#     809 # Pre-compute histogram scaling factor
#     810 norm_numerator = n_equal_bins
# --> 811 norm_denom = _unsigned_subtract(last_edge, first_edge)
#     813 # We iterate over blocks here for two reasons: the first is that for
#     814 # large arrays, it is actually faster (for example for a 10^8 array it
#     815 # is 2x as fast) and it results in a memory footprint 3x lower in the
#     816 # limit of large arrays.
#     817 for i in _range(0, len(a), BLOCK):
#
# File ~/opt/anaconda3/envs/astronomy_general/lib/python3.9/site-packages/numpy/lib/histograms.py:353, in _unsigned_subtract(a, b)
#     351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
# --> 353     return np.subtract(a, b, dtype=dt)
#     354 else:
#     355     # we know the inputs are integers, and we are deliberately casting
#     356     # signed to unsigned
#     357     return np.subtract(a, b, casting='unsafe', dtype=dt)
#
# TypeError: numpy boolean subtract, the `-` operator, is not supported, use the bitwise_xor, the `^` operator, or the logical_xor function instead.

# %%
masses = np.array(data['mass_flame'].notnull())
np.mean(data[masses]['mass_flame'])
# Out:
# 0.9207613773407143

# %%
metals = np.array(data['mh_gspphot'].notnull())
np.mean(data[masses]['mh_gspphot'])
# Out:
# -0.23278060384734078

# %%
# radial velocities seem to be magnitude-limited
has_radvel = np.array(data['mass_flame'].notnull())
no_radvel = np.logical_not(has_radvel)


fig,ax = plt.subplots(figsize=(8,5))
ax.hist([data[has_radvel]['PARALLAX'], data[no_radvel]['PARALLAX']], stacked="True",\
    bins = np.linspace(5, 20),\
    label = ["with mass", "without mass"],\
    color = ["steelblue", "darkblue"])
#ax.hist(df_without_vel["Gmag"], stacked = True)
ax.set_yscale("log")

ax.legend()

ax.set_xlabel("Parallax", fontsize = 12)
ax.set_ylabel("Number of Stars per Bin", fontsize = 12)

plt.show()
