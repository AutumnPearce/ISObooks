# %% [markdown]
# # Compare the values collected by Gaia DR3 and Gaia EDR3

# %%
# imports
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# grab data
dr3 = pd.read_csv('../files/gcns_DR3.csv')
edr3 = pd.read_csv('../files/gcns_EDR3.csv')

# %%
edr3
# Out:
#         Unnamed: 0             GaiaEDR3       RAdeg  e_RAdeg      DEdeg  \
# 0                0  2334666126716440064    0.002565  0.03305 -26.365350
# 1                1  2341871673090078592    0.005121  0.42837 -19.498841
# 2                2   530861741656374272    0.005637  0.00951  70.887364
# 3                3  2745400068346761216    0.009336  0.03793   6.511017
# 4                4  2855176271335676800    0.013536  0.02864  29.277896
# ...            ...                  ...         ...      ...        ...
# 331307      331307  2766925825958528512  359.993523  0.03391  12.376062
# 331308      331308  2773791481503524992  359.994028  0.22628  18.053030
# 331309      331309  6521388186590534272  359.994771  0.01233 -53.182288
# 331310      331310  2011682661920690304  359.995813  0.46508  60.918306
# 331311      331311  2314850075324449408  359.999926  0.24543 -30.024529
#
#         e_DEdeg     Plx    e_Plx     pmRA   e_pmRA  ...  e_Ksmag  \
# ...

# %%
dr3
# Out:
#         Unnamed: 0            source_id          RA  RA_ERROR        DEC  \
# 0                0   383095247260963712    2.058686  0.022047  39.728708
# 1                1   383108338321272448    1.977553  0.038781  39.791932
# 2                2   383162661067592192    1.680234  0.128044  40.009855
# 3                3   383167952465316864    1.905896  0.021587  40.147840
# 4                4   383167952467292288    1.907764  0.225813  40.147854
# ...            ...                  ...         ...       ...        ...
# 331306      331306  6533471819377716736  358.771159  0.009305 -41.401665
# 331307      331307  6533483501688768128  358.651669  0.019821 -41.321624
# 331308      331308  6533503464696796928  359.239473  0.008948 -41.013088
# 331309      331309  6533503464696797056  359.237353  0.033996 -41.012712
# 331310      331310  6533569023077625984  358.599516  0.026710 -40.747478
#
#         DEC_ERROR   PARALLAX  PARALLAX_ERROR        PMRA  PMRA_ERROR  ...  \
# ...

# %%
dr3['source_id'].sort_values
# Out:
# <bound method Series.sort_values of 0          383095247260963712
# 1          383108338321272448
# 2          383162661067592192
# 3          383167952465316864
# 4          383167952467292288
#                  ...
# 331306    6533471819377716736
# 331307    6533483501688768128
# 331308    6533503464696796928
# 331309    6533503464696797056
# 331310    6533569023077625984
# Name: source_id, Length: 331311, dtype: int64>

# %%
edr3['GaiaEDR3'].sort_values
# Out:
# <bound method Series.sort_values of 0         2334666126716440064
# 1         2341871673090078592
# 2          530861741656374272
# 3         2745400068346761216
# 4         2855176271335676800
#                  ...
# 331307    2766925825958528512
# 331308    2773791481503524992
# 331309    6521388186590534272
# 331310    2011682661920690304
# 331311    2314850075324449408
# Name: GaiaEDR3, Length: 331312, dtype: int64>
